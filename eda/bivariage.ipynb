# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns',200)

tit = pd.read_csv('F:/DSA/practical/ML/dataset/tit.csv')

flights = sns.load_dataset('flights')
flights.head()

iris = sns.load_dataset('iris')
iris.head()

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 1. scatterplot ( Numerical - Numerical)

# %%
###??? Multivariate analysis >>>>>>>>>>>>>>>>>>>>>>>
sns.scatterplot(tips, x = 'total_bill',y = 'tip',hue='sex',style='smoker',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## 2. Bar plot ( numerical - categorical )

# %%
sns.barplot(tit , x = 'Pclass' , y = 'Age')
sns.barplot(tit,x='Pclass',y='Fare',hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# ## 3. Box plot ( Numerical - categorical )

# %%
sns.boxplot(tit,x='Sex',y='Age',hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# ### 4. Distplot ( Numerical - Categorical )

# %%
#### PDF ( Probability density function)
# sns.distplot(tit[tit['Survived'] == 0]['Age'] )
# sns.distplot(tit[tit['Survived'] == 1 ]['Age'])

### turning off the histogram 
sns.distplot(tit[tit['Survived'] == 0]['Age'] , hist=False)
sns.distplot(tit[tit['Survived'] == 1 ]['Age'],hist=False)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4952\1771763956.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tit[tit['Survived'] == 0]['Age'] , hist=False)
# C:\Users\HP\AppData\Local\Temp\ipykernel_4952\1771763956.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ## 5. HeatMap ( Categorical - Categorical )

# %%
pd.crosstab(tit['Pclass'],tit['Survived'])

sns.heatmap(pd.crosstab(tit['Pclass'],tit['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %% [markdown]
# ## 6. ClusterMap ( Catorical - Categorical )

# %%
tit.groupby('Pclass')

# %% [markdown]
# ## 6. Clustermap ( Categorical - Categorical )

# %%
pd.crosstab(tit['SibSp'], tit['Survived'])

sns.clustermap(pd.crosstab(tit['Parch'],tit['Survived']))

# %% [markdown]
# ## 7. Pairplot

# %%
iris.head()
# sns.pairplot(iris)
sns.pairplot(tit)
