# %%
import pandas as pd
df = pd.read_csv('F:/DSA/practical/ML/tit.csv')

bamu = pd.read_csv('F:/Data science/Data analysis/data filtered/bamudb.csv')
df.head()
bamu.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10656\2092536576.py:4: DtypeWarning: Columns (3,24,25,26,78,85,120,135,137,144,146,147,256,259,260,261,262,263,265,266,267,303,304,305,308,309,310,311,312,313,553,554,556,557,560,577,578,579,591,681,699,700,701,702,709) have mixed types. Specify dtype option on import or set low_memory=False.
#   bamu = pd.read_csv('F:/Data science/Data analysis/data filtered/bamudb.csv')
#    Unnamed: 0  FORM.NUMBER                    PROGRAMME.NAME ORDER.ID  \
# 0           1           90  MASTER OF SCIENCE(BIO-CHEMISTRY)       67
# 1           2          255  MASTER OF SCIENCE(BIO-CHEMISTRY)      191
# 2           3          258  MASTER OF SCIENCE(BIO-CHEMISTRY)      194
# 3           4          510  MASTER OF SCIENCE(BIO-CHEMISTRY)     1516
# 4           5          617  MASTER OF SCIENCE(BIO-CHEMISTRY)      652
#
#   ALIAS.ORDER.NUMBER   TRANSACTION.ID BANK.REFERENCE.NUMBER  AMOUNT.PAID  \
# 0      202425XREGX67    202425XREGX67           4.13747E+11          100
# 1     202425XREGX191   202425XREGX191           4.13841E+11          100
# 2     202425XREGX194   202425XREGX194           4.13875E+11          200
# 3    202425XREGX1516  202425XREGX1516           4.14428E+11          100
# 4     202425XREGX652   202425XREGX652           4.14286E+11          200
#
#       PAYMENT.DATE  STUDY.CENTRE  ...  OU.CENTER.PREFERENCE.3  \
# 0  5/15/2024 18:56           NaN  ...                     NaN
# 1  5/17/2024 13:05           NaN  ...                     NaN
# 2  5/17/2024 13:29           NaN  ...                     NaN
# 3  5/23/2024 16:51           NaN  ...                     NaN
# 4   5/21/2024 6:28           NaN  ...                     NaN
#
#   OU.CENTER.PREFERENCE.4 OU.CENTER.PREFERENCE.5  OU.CENTER.PREFERENCE.6  \
# 0                    NaN                    NaN                     NaN
# 1                    NaN                    NaN                     NaN
# 2                    NaN                    NaN                     NaN
# 3                    NaN                    NaN                     NaN
# 4                    NaN                    NaN                     NaN
#
#   OU.CENTER.PREFERENCE.7 OU.CENTER.PREFERENCE.8 OU.CENTER.PREFERENCE.9  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#   OU.CENTER.PREFERENCE.10 OU.CENTER.PREFERENCE.11  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
#
#    NOT.APPLICABLE.OU.PREFERENCE
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 816 columns]

# %% [markdown]
# # 1. How big is the data?

# %%
df.shape
bamu.shape
# Out:
# (18736, 816)

# %% [markdown]
# # 2. How does the data look like?

# %%
df.head()
df.sample(5)
bamu.sample(5)
# Out:
#        Unnamed: 0  FORM.NUMBER  \
# 18047       18048        15355
# 2051         2052         1031
# 1571         1572         2202
# 10710       10711        21156
# 3645         3646        17114
#
#                                           PROGRAMME.NAME ORDER.ID  \
# 18047  DOCTOR OF PHILOSOPHY(MANAGEMENT SCIENCE - COMP...    21243
# 2051   MASTER OF FINE ARTS ( APPLIED ARTS) VISUALIZATION     1237
# 1571                 MASTER OF SCIENCE(FORENSIC SCIENCE)     2510
# 10710                      DOCTOR OF PHILOSOPHY(ZOOLOGY)    25494
# 3645                        MASTER OF COMMERCE(COMMERCE)    21544
#
#       ALIAS.ORDER.NUMBER    TRANSACTION.ID BANK.REFERENCE.NUMBER  AMOUNT.PAID  \
# 18047   202425XREGX21243  202425XREGX21243           4.21393E+11         1000
# 2051     202425XREGX1237   202425XREGX1237           4.14456E+11          100
# 1571     202425XREGX2510   202425XREGX2510           4.14698E+11          200
# 10710   202425XREGX25494  202425XREGX25494           4.22733E+11         1000
# 3645    202425XREGX21544  202425XREGX21544           4.21581E+11          100
#
#           PAYMENT.DATE  STUDY.CENTRE  ...  OU.CENTER.PREFERENCE.3  \
# 18047  7/31/2024 18:12           NaN  ...                     NaN
# 2051    5/23/2024 4:41           NaN  ...                     NaN
# 1571    5/25/2024 8:58           NaN  ...                     NaN
# 10710   8/14/2024 8:32           NaN  ...                     NaN
# 3645     8/2/2024 7:09           NaN  ...                     NaN
#
#       OU.CENTER.PREFERENCE.4 OU.CENTER.PREFERENCE.5  OU.CENTER.PREFERENCE.6  \
# 18047                    NaN                    NaN                     NaN
# 2051                     NaN                    NaN                     NaN
# 1571                     NaN                    NaN                     NaN
# 10710                    NaN                    NaN                     NaN
# 3645                     NaN                    NaN                     NaN
#
#       OU.CENTER.PREFERENCE.7 OU.CENTER.PREFERENCE.8 OU.CENTER.PREFERENCE.9  \
# 18047                    NaN                    NaN                    NaN
# 2051                     NaN                    NaN                    NaN
# 1571                     NaN                    NaN                    NaN
# 10710                    NaN                    NaN                    NaN
# 3645                     NaN                    NaN                    NaN
#
#       OU.CENTER.PREFERENCE.10 OU.CENTER.PREFERENCE.11  \
# 18047                     NaN                     NaN
# 2051                      NaN                     NaN
# 1571                      NaN                     NaN
# 10710                     NaN                     NaN
# 3645                      NaN                     NaN
#
#        NOT.APPLICABLE.OU.PREFERENCE
# 18047                           NaN
# 2051                            NaN
# 1571                            NaN
# 10710                           NaN
# 3645                            NaN
#
# [5 rows x 816 columns]

# %% [markdown]
# # 3. what is the data type of cols?

# %%
df.info()
bamu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18736 entries, 0 to 18735
# Columns: 816 entries, Unnamed: 0 to NOT.APPLICABLE.OU.PREFERENCE
# dtypes: float64(619), int64(18), object(179)
# memory usage: 116.6+ MB

# %% [markdown]
# # 4. Are there any missing values?

# %%
df.isnull().sum()
bamu.isnull().sum()
# Out:
# Unnamed: 0                          0
# FORM.NUMBER                         0
# PROGRAMME.NAME                      0
# ORDER.ID                            0
# ALIAS.ORDER.NUMBER                 17
#                                 ...
# OU.CENTER.PREFERENCE.8          18736
# OU.CENTER.PREFERENCE.9          18736
# OU.CENTER.PREFERENCE.10         18736
# OU.CENTER.PREFERENCE.11         18736
# NOT.APPLICABLE.OU.PREFERENCE    18736
# Length: 816, dtype: int64

# %% [markdown]
# # 5. How does the data look Mathematically?

# %%
df.describe()
bamu.describe()
# Out:
#          Unnamed: 0   FORM.NUMBER   AMOUNT.PAID  STUDY.CENTRE  \
# count  18736.000000  18736.000000  18736.000000           0.0
# mean    9368.500000  12229.276260    545.906277           NaN
# std     5408.761657   7080.356104    317.582442           NaN
# min        1.000000     12.000000      0.000000           NaN
# 25%     4684.750000   6191.750000    500.000000           NaN
# 50%     9368.500000  12121.500000    500.000000           NaN
# 75%    14052.250000  18393.500000   1000.000000           NaN
# max    18736.000000  24630.000000   1000.000000           NaN
#
#        PROGRAM.PREFERENCE  HINDI.NAME.OF.THE.APPLICANT  MARITAL.STATUS  \
# count        18736.000000                          0.0             0.0
# mean             1.055615                          NaN             NaN
# std              0.270619                          NaN             NaN
# min              1.000000                          NaN             NaN
# 25%              1.000000                          NaN             NaN
# 50%              1.000000                          NaN             NaN
# 75%              1.000000                          NaN             NaN
# max              6.000000                          NaN             NaN
#
#        SECOND.LANGUAGE.STUDIED.IN.XII  RESIDENCE.AREA  SIKKIMESE.CERTIFICATE  \
# count                             0.0             0.0                    0.0
# mean                              NaN             NaN                    NaN
# std                               NaN             NaN                    NaN
# min                               NaN             NaN                    NaN
# 25%                               NaN             NaN                    NaN
# 50%                               NaN             NaN                    NaN
# 75%                               NaN             NaN                    NaN
# max                               NaN             NaN                    NaN
#
#        ...  OU.CENTER.PREFERENCE.3  OU.CENTER.PREFERENCE.4  \
# count  ...                     0.0                     0.0
# mean   ...                     NaN                     NaN
# std    ...                     NaN                     NaN
# min    ...                     NaN                     NaN
# 25%    ...                     NaN                     NaN
# 50%    ...                     NaN                     NaN
# 75%    ...                     NaN                     NaN
# max    ...                     NaN                     NaN
#
#        OU.CENTER.PREFERENCE.5  OU.CENTER.PREFERENCE.6  OU.CENTER.PREFERENCE.7  \
# count                     0.0                     0.0                     0.0
# mean                      NaN                     NaN                     NaN
# std                       NaN                     NaN                     NaN
# min                       NaN                     NaN                     NaN
# 25%                       NaN                     NaN                     NaN
# 50%                       NaN                     NaN                     NaN
# 75%                       NaN                     NaN                     NaN
# max                       NaN                     NaN                     NaN
#
#        OU.CENTER.PREFERENCE.8  OU.CENTER.PREFERENCE.9  \
# count                     0.0                     0.0
# mean                      NaN                     NaN
# std                       NaN                     NaN
# min                       NaN                     NaN
# 25%                       NaN                     NaN
# 50%                       NaN                     NaN
# 75%                       NaN                     NaN
# max                       NaN                     NaN
#
#        OU.CENTER.PREFERENCE.10  OU.CENTER.PREFERENCE.11  \
# count                      0.0                      0.0
# mean                       NaN                      NaN
# std                        NaN                      NaN
# min                        NaN                      NaN
# 25%                        NaN                      NaN
# 50%                        NaN                      NaN
# 75%                        NaN                      NaN
# max                        NaN                      NaN
#
#        NOT.APPLICABLE.OU.PREFERENCE
# count                           0.0
# mean                            NaN
# std                             NaN
# min                             NaN
# 25%                             NaN
# 50%                             NaN
# 75%                             NaN
# max                             NaN
#
# [8 rows x 637 columns]

# %% [markdown]
# # 6. Are there any duplicates values ?

# %%
df.duplicated().sum()
bamu.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 7. How is the correlation between cols?

# %%
df.corr()['Survived']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df.corr()['Survived']
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Braund, Mr. Owen Harris'
